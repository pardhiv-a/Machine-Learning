# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2c46a8e9-c1a3-4bff-a6a0-69381d439866" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c46a8e9-c1a3-4bff-a6a0-69381d439866">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-550f2848-c482-43f8-8057-a64bde692289" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-550f2848-c482-43f8-8057-a64bde692289">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-82b24c95-765e-428a-add1-0e271b110d2c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-82b24c95-765e-428a-add1-0e271b110d2c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5fa5b282-c88c-421e-9798-297a518011c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5fa5b282-c88c-421e-9798-297a518011c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# A4:
from sklearn.neighbors import KNeighborsClassifier

# A4: Generate test grid data from 0 to 10 with 0.1 step
x_vals = np.arange(0, 10.1, 0.1)
y_vals = np.arange(0, 10.1, 0.1)
xx, yy = np.meshgrid(x_vals, y_vals)
X_test = np.c_[xx.ravel(), yy.ravel()]  # Shape: (10000, 2)

# Prepare training data
X = df[["X", "Y"]].values # Corrected from df_train to df
y = df["Class"].values   # Corrected from df_train to df

# Train kNN classifier with k=3
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X, y)

# Predict on test grid
y_pred = knn.predict(X_test)

# Plot the results
plt.figure(figsize=(10, 8))
# Test data prediction color
plt.scatter(X_test[:, 0], X_test[:, 1], c=np.where(y_pred == 0, 'blue', 'red'), s=10, alpha=0.3, marker='s')

# Overlay training data
plt.scatter(X[:, 0], X[:, 1], c=np.where(y == 0, 'blue', 'red'), s=100, edgecolor='black')

plt.title("A4: kNN Classification (k=3) of Test Grid Data")
plt.xlabel("Feature X")
plt.ylabel("Feature Y")
plt.grid(True)
plt.show()
